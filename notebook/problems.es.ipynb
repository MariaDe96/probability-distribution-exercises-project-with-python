# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2 import numpy as np
#       4 np.random.seed(42)
# ----> 6 print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
#       7 print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
#       8 print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
#
# NameError: name 'dbinom' is not defined

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# TODO
# Normal 

from scipy.stats import norm

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dnorm(x, mean = 0, std= 1):
    result = norm.pdf(x, loc = mean, scale=std)
    return result

def pnorm(q, mean=0, std=1):
    result = norm.cdf(q, loc = mean, scale=std)
    return result

def qnorm(p, mean=0, std=1):
    result = norm.ppf(p, loc = mean, scale=std)
    return result

def rnorm(n, mean=0, std=1):
    result = norm.rvs(loc = mean, scale=std, size=n)
    return result

# uniforme


from scipy.stats import norm

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dunif(x, low= 0, high = 1):
    result = norm.pdf(x, loc = low, scale=high-low)
    return result

def punif(q, low=0, high=1):
    result = norm.cdf(q, loc = low, scale=high-low)
    return result

def qunif(p, low=0, high=1):
    result = norm.ppf(p, loc = low, scale=high-low)
    return result

def runif(n, low=0, high=1):
    result = norm.rvs(loc = low, scale=high-low, size=n)
    return result

# %%
from scipy.stats import norm
import numpy as np

np.random.seed(42)
x= 1
print(f"Probability Density at x={x} for Normal(0, 1): {dnorm(x, mean=0, std=1)}")
print(f"Probability that Normal(0, 1) <= {x}: {pnorm(x, mean=0, std=1)}")
print(f"Which value of Normal(0, 1) has cumulative probability 0.9? {qnorm(0.9, mean=0, std=1)}")
print(f"Generate 2000 random values from Normal(0, 1): {rnorm(2000, mean=0, std=1)}")

from scipy.stats import uniform
import numpy as np

np.random.seed(42)
x= 0.5
print(f"Probability Density at x={x} for Uniform(0, 1): {dunif(x, low=0, high=1)}")
print(f"Probability that Uniform(0, 1) <= {x}: {punif(x, low=0, high=1)}")
print(f"Which value of Uniform(0, 1) has cumulative probability 0.9? {qunif(0.9, low=0, high=1)}")
print(f"Generate 2000 random values from Uniform(0, 1): {runif(2000, low=0, high=1)}")
# Out:
# Probability Density at x=1 for Normal(0, 1): 0.24197072451914337
# Probability that Normal(0, 1) <= 1: 0.8413447460685429
# Which value of Normal(0, 1) has cumulative probability 0.9? 1.2815515655446004
# Generate 2000 random values from Normal(0, 1): [ 0.49671415 -0.1382643   0.64768854 ... -0.88187465 -0.16306696
#  -0.74490264]
# Probability Density at x=0.5 for Uniform(0, 1): 0.35206532676429947
# Probability that Uniform(0, 1) <= 0.5: 0.6914624612740131
# Which value of Uniform(0, 1) has cumulative probability 0.9? 1.2815515655446004
# Generate 2000 random values from Uniform(0, 1): [ 0.49671415 -0.1382643   0.64768854 ... -0.88187465 -0.16306696
#  -0.74490264]

# %%
import matplotlib.pyplot as plt
# parametros
mean = 0
std = 1
data = rnorm(2000, mean= 0 , std=1)

pmf = dnorm(data, mean=0 , std=1)
cdf = pnorm(data, mean=0 , std=1)
ppf = qnorm(cdf, mean=0 , std=1)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
# parametros
low= 0
high= 1
data = runif(2000, low=0 , high=1)

pmf = dunif(data, low=0 , high=1)
cdf = punif(data, low=0 , high=1)
ppf = qunif(cdf, low=0 , high=1)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
